# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Dropout,MaxPooling2D,Flatten
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import random
print(tf.__version__)
# Out:
# 2.9.1

# %%
df = pd.read_csv('fashionMnist_new2.csv')

# %%
df_cd_temp = df

# %% [markdown]
# # normal model

# %%
myacc = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    data = df.sample(frac=1, random_state=myround)
    df_train = data.iloc[:20000,:]
    df_test = data.iloc[20000:22000,:]
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)

        from keras.models import load_model
        model = load_model('FashionMnistNormal'+ str(myround) + '.h5')
        myacc[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4df2a5e7cb5f> in <module>
#      27
#      28         from keras.models import load_model
# ---> 29         model = load_model('FashionMnistNormal'+ str(myround) + '.h5')
#      30         myacc[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py in _process_kwargs(self, kwargs)
#      92             ", please check the docstring for valid arguments.", k)
#      93       else:
# ---> 94         raise TypeError(f"{k} is not a valid argument, kwargs should be empty "
#      95                         " for `optimizer_experimental.Optimizer`.")
#      96
#
# TypeError: weight_decay is not a valid argument, kwargs should be empty  for `optimizer_experimental.Optimizer`.

# %%
myacc

# %%
nn = 0
meanPerBin = np.zeros(5)
for myturn in range (5):
    meanPerBin[myturn] = np.mean(myacc[:, myturn])
    nn += (np.mean(myacc[:, myturn]))
print(nn/5)
meanPerBin

# %%
myhist = np.zeros((20,5))

for myround in range(1,21):
    df_cd = df_cd_temp.sample(frac=1, random_state=myround)
    df_cd1 =  df_cd#.drop(columns="Dffclt")
    df_train = df_cd1.iloc[:20000,:]
    df_test = df_cd1.iloc[20000:22000,:]
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        myhist[myround-1,mydiff] = len(df_test_temp)
myhist

# %%
myhistAccum = np.zeros (5)
for histindex in range (5):
    myhistAccum[histindex] = np.sum(myhist[:, histindex])
print(myhistAccum)

# %%
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccum, color='green')
plt.title("number of instances per bin(normal dataset)")
plt.show()

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
plt.rcParams['figure.figsize'] = [14, 8]
#plt.ylim([0, 105])
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls=':', color = 'green')
plt.show()

# %%
#meanPerBin = [0.79911429, 0.8317701 , 0.8279106 , 0.81521758, 0.81394129,0.79659775, 0.78136204, 0.7744887 , 0.74064942, 0.67989944]
meanPerBin = np.array([0.99950602, 0.99847758, 0.9919301,  0.92959095, 0.59056556])

# %% [markdown]
# # contaminated model

# %%
myaccCont = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    df_cd = df.sample(frac=1, random_state=myround)
    hardest = df_cd[25000:]
    hardest = hardest.sort_values('Dffclt', ascending=False)
#     hardest =  hardest.drop(columns="Dffclt")
    hardest = hardest.iloc[:11000,:]
    hardest = hardest.sample(frac=1, random_state=myround)
    contaminated_trianset = hardest.iloc[:10000,:]
    hardest = hardest.iloc[10000:11000,:]
    data = df_cd#.drop(columns="Dffclt")
    df_train = data.iloc[:10000,:]
    df_train = df_train.append(contaminated_trianset, ignore_index=True)
    df_train = df_train.sample(frac=1, random_state=myround)
    df_test = data.iloc[20000:21000,:]
    df_test = df_test.append(hardest, ignore_index=True)
    df_test = df_test.sample(frac=1, random_state=myround)
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)
        from keras.models import load_model
        model = load_model('FashionMnistContaminated'+ str(myround) + '.h5')
        myaccCont[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-fcc139461ba3> in <module>
#      37         testY = np_utils.to_categorical(testY,10)
#      38         from keras.models import load_model
# ---> 39         model = load_model('FashionMnistContaminated'+ str(myround) + '.h5')
#      40         myaccCont[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# D:\Program Files (x86)\Anaconda\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py in _process_kwargs(self, kwargs)
#      92             ", please check the docstring for valid arguments.", k)
#      93       else:
# ---> 94         raise TypeError(f"{k} is not a valid argument, kwargs should be empty "
#      95                         " for `optimizer_experimental.Optimizer`.")
#      96
#
# TypeError: weight_decay is not a valid argument, kwargs should be empty  for `optimizer_experimental.Optimizer`.

# %%
myaccCont
# Out:
# array([[0.89952153, 0.88481677, 0.907767  , 0.90640396, 0.91295546],
#        [0.89320385, 0.88764048, 0.92592591, 0.89322919, 0.90220517],
#        [0.87684727, 0.91627908, 0.92195123, 0.89830506, 0.913001  ],
#        [0.88732392, 0.90769231, 0.91500002, 0.90237468, 0.90325767],
#        [0.90497738, 0.86597937, 0.86818182, 0.89398283, 0.90059054],
#        [0.9375    , 0.89999998, 0.91121495, 0.91773778, 0.89990091],
#        [0.92307693, 0.8917526 , 0.884058  , 0.8938992 , 0.90652388],
#        [0.90206188, 0.89952153, 0.91443849, 0.88833749, 0.90963256],
#        [0.90306121, 0.86390531, 0.89393938, 0.92647058, 0.91448009],
#        [0.90547264, 0.90109891, 0.87782806, 0.90575916, 0.91321498],
#        [0.90594059, 0.89423078, 0.91623038, 0.922252  , 0.9152047 ],
#        [0.880597  , 0.90206188, 0.8952381 , 0.90726817, 0.90662652],
#        [0.88625592, 0.8888889 , 0.91000003, 0.91223407, 0.90457255],
#        [0.89999998, 0.90769231, 0.92424244, 0.90231365, 0.90277779],
#        [0.93969852, 0.93000001, 0.89150941, 0.93817204, 0.89380533],
#        [0.89047617, 0.87113404, 0.90052354, 0.87146533, 0.89665353],
#        [0.88770056, 0.8761062 , 0.9009009 , 0.9160105 , 0.90955287],
#        [0.91469193, 0.93627453, 0.91752577, 0.91773778, 0.88522953],
#        [0.91457283, 0.88235295, 0.87179488, 0.8953771 , 0.90716445],
#        [0.90306121, 0.87111109, 0.87179488, 0.9018088 , 0.90270811]])

# %%
nnCont = 0
meanPerBinCont = np.zeros(5)
for myturn in range (5):
    meanPerBinCont[myturn] = np.mean(myaccCont[:, myturn])
    nnCont += (np.mean(myaccCont[:, myturn]))
print(nnCont/5)
meanPerBinCont
# Out:
# 0.9016584253311157
# array([0.90280207, 0.89392695, 0.90100326, 0.90555697, 0.90500288])

# %%
myhistCont = np.zeros((20,5))

for myround in range(1,21):
    df_cd = df_cd_temp.sample(frac=1, random_state=myround)
    hardest= df_cd[25000:]
    hardest=hardest.sort_values('Dffclt', ascending=False)
    #hardest=  hardest.drop(columns="Dffclt")
    hardest = hardest.iloc[:11000,:]
    shuffled_hardest = hardest.sample(frac=1, random_state=myround)
    contaminated_trianset = shuffled_hardest.iloc[:10000,:]
    hardest = shuffled_hardest.iloc[10000:11000,:]
    df_cd1 =  df_cd#.drop(columns="Dffclt")
    df_train = df_cd1.iloc[:10000,:]
    df_train = df_train.append(contaminated_trianset, ignore_index=True)
    df_train = df_train.sample(frac=1, random_state=myround)
    df_train = df_train.drop(columns="Dffclt")
    df_test = df_cd1.iloc[20000:21000,:]
    df_test = df_test.append(hardest, ignore_index=True)
    df_test = df_test.sample(frac=1, random_state=myround)
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        myhistCont[myround-1,mydiff] = len(df_test_temp)
myhistCont
# Out:
# array([[ 209.,  191.,  206.,  406.,  988.],
#        [ 206.,  178.,  189.,  384., 1043.],
#        [ 203.,  215.,  205.,  354., 1023.],
#        [ 213.,  195.,  200.,  379., 1013.],
#        [ 221.,  194.,  220.,  349., 1016.],
#        [ 208.,  180.,  214.,  389., 1009.],
#        [ 195.,  194.,  207.,  377., 1027.],
#        [ 194.,  209.,  187.,  403., 1007.],
#        [ 196.,  169.,  198.,  408., 1029.],
#        [ 201.,  182.,  221.,  382., 1014.],
#        [ 202.,  208.,  191.,  373., 1026.],
#        [ 201.,  194.,  210.,  399.,  996.],
#        [ 211.,  207.,  200.,  376., 1006.],
#        [ 210.,  195.,  198.,  389., 1008.],
#        [ 199.,  200.,  212.,  372., 1017.],
#        [ 210.,  194.,  191.,  389., 1016.],
#        [ 187.,  226.,  222.,  381.,  984.],
#        [ 211.,  204.,  194.,  389., 1002.],
#        [ 199.,  204.,  195.,  411.,  991.],
#        [ 196.,  225.,  195.,  387.,  997.]])

# %%
myhistAccumCont = np.zeros (5)
for histindex in range (5):
    myhistAccumCont[histindex] = np.sum(myhistCont[:, histindex])
print(myhistAccumCont)
# Out:
# [ 4072.  3964.  4055.  7697. 20212.]

# %%
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccum,width=0.7, color='green')
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccumCont,width=0.3, color = 'red')

plt.title("number of instances per bin(contaminated dataset)")
plt.show()

# %%
meanPerBinCont = np.array([0.99756604, 0.98880464, 0.97472332, 0.87867653, 0.66231571])

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
plt.rcParams['figure.figsize'] = [14, 8]
#plt.ylim([0, 105])
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont*100, ls='-', color = 'red')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls=':', color = 'green')
plt.show()

# %% [markdown]
# # Contaminate model on normal data

# %%
myaccCont_nor = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    data = df.sample(frac=1, random_state=myround)
    df_train = data.iloc[:20000,:]
    df_test = data.iloc[20000:22000,:]
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)
        from keras.models import load_model
        model = load_model('FashionMnistContaminated'+ str(myround) + '.h5')
        myaccCont_nor[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3010 - accuracy: 0.9082
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2949 - accuracy: 0.9115
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3386 - accuracy: 0.9065
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.9041
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3778 - accuracy: 0.8918
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3074 - accuracy: 0.8997
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3521 - accuracy: 0.9049
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3546 - accuracy: 0.9277
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4137 - accuracy: 0.8833
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3116 - accuracy: 0.9272
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4507 - accuracy: 0.8985
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2920 - accuracy: 0.9067
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3196 - accuracy: 0.8983
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8939
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3495 - accuracy: 0.9095
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4038 - accuracy: 0.8753
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4109 - accuracy: 0.8842
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3152 - accuracy: 0.9025
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4188 - accuracy: 0.8869
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2896 - accuracy: 0.9003
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2813 - accuracy: 0.9129
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4181 - accuracy: 0.8737
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4127 - accuracy: 0.8771
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3634 - accuracy: 0.9135
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2690 - accuracy: 0.9254
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2745 - accuracy: 0.9233
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4720 - accuracy: 0.8924
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3596 - accuracy: 0.9162
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4004 - accuracy: 0.9121
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3585 - accuracy: 0.9068
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4076 - accuracy: 0.9000
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4220 - accuracy: 0.9013
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4129 - accuracy: 0.8846
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4047 - accuracy: 0.9002
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4221 - accuracy: 0.8958
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.9031
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2937 - accuracy: 0.9082
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3125 - accuracy: 0.9039
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4633 - accuracy: 0.8723
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4138 - accuracy: 0.8923
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3276 - accuracy: 0.8997
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5462 - accuracy: 0.8773
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4003 - accuracy: 0.8990
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2865 - accuracy: 0.9106
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.9111
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2786 - accuracy: 0.9187
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5267 - accuracy: 0.8964
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.9071
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3877 - accuracy: 0.9160
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.9236
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4135 - accuracy: 0.8861
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2424 - accuracy: 0.9108
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3598 - accuracy: 0.8974
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5035 - accuracy: 0.8781
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3364 - accuracy: 0.8946
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.8957
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3164 - accuracy: 0.9029
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2851 - accuracy: 0.9035
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3745 - accuracy: 0.9133
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3559 - accuracy: 0.8947
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3278 - accuracy: 0.9009
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2799 - accuracy: 0.8911
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4001 - accuracy: 0.9016
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2678 - accuracy: 0.9183
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.9086
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3416 - accuracy: 0.9128
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2712 - accuracy: 0.9125
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2759 - accuracy: 0.9143
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3692 - accuracy: 0.8908
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3748 - accuracy: 0.9128
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3790 - accuracy: 0.8965
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2577 - accuracy: 0.9093
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3924 - accuracy: 0.8929
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3222 - accuracy: 0.9119
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2793 - accuracy: 0.9052
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3281 - accuracy: 0.8986
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3927 - accuracy: 0.8985
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4002 - accuracy: 0.8852
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3836 - accuracy: 0.8892
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2932 - accuracy: 0.9051
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3031 - accuracy: 0.8967
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8824
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3787 - accuracy: 0.9089
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3683 - accuracy: 0.8984
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3890 - accuracy: 0.9000
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2518 - accuracy: 0.9284
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3050 - accuracy: 0.9163
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3886 - accuracy: 0.9025
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2743 - accuracy: 0.9309
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3330 - accuracy: 0.9196
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.9186
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3190 - accuracy: 0.9008
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3158 - accuracy: 0.8911
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4171 - accuracy: 0.8939
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3958 - accuracy: 0.8971
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3291 - accuracy: 0.9008
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3734 - accuracy: 0.8918
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3750 - accuracy: 0.9020
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3790 - accuracy: 0.8950
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2475 - accuracy: 0.9415

# %%
nnCont_nor = 0
meanPerBinCont_nor = np.zeros(5)
for myturn in range (5):

    meanPerBinCont_nor[myturn] = np.mean(myaccCont_nor[:, myturn])
    nnCont_nor += (np.mean(myaccCont_nor[:, myturn]))
print(nnCont_nor/5)
meanPerBinCont_nor
# Out:
# 0.9024561089277269
# array([0.90373788, 0.89864144, 0.90110891, 0.90063284, 0.90815947])

# %%
myhistCont_nor = np.zeros((5,10))

for myroundCont_nor in range(1,6):
    df_cd = df_cd_temp.sample(frac=1, random_state=myroundCont_nor)
    df_cd1 =  df_cd#.drop(columns="Dffclt")
    df_train = df_cd1.iloc[:20000,:]
    df_test = df_cd1.iloc[20000:22000,:]
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        myhistCont_nor[myroundCont_nor-1,mydiff] = len(df_test_temp)
myhistCont_nor
# Out:
# array([[403., 384., 417., 417., 379.,   0.,   0.,   0.,   0.,   0.],
#        [399., 368., 401., 420., 412.,   0.,   0.,   0.,   0.,   0.],
#        [394., 418., 413., 377., 398.,   0.,   0.,   0.,   0.,   0.],
#        [425., 406., 400., 398., 371.,   0.,   0.,   0.,   0.,   0.],
#        [402., 380., 423., 393., 402.,   0.,   0.,   0.,   0.,   0.]])

# %%
myhistAccumCont_nor = np.zeros (5)
for histindex in range (5):
    myhistAccumCont_nor[histindex] = np.sum(myhistCont_nor[:, histindex])
print(myhistAccumCont_nor)
# Out:
# [2023. 1956. 2054. 2005. 1962.]

# %%
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccumCont_nor)
plt.title("number of instances per bin(normal dataset)")
plt.show()

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
#plt.ylim([0, 100])
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont*100, ls='-', color = 'red')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls='-', color = 'green')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont_nor*100, ls='-.', color = 'blue')
plt.legend(["M',D'","M,D", "M',D"])
plt.show()

# %% [markdown]
# # Balanced dataset

# %%
myaccBal = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    df_cd = df.sample(frac=1, random_state=myround)
    hardest = df_cd[25000:]
    hardest = hardest.sort_values('Dffclt', ascending=False)
    hardestbalanced = hardest[:1]
    for item_class in range (10):
        hardestTemp = hardest[hardest['class']==item_class]
        hardestbalanced = hardestbalanced.append(hardestTemp.iloc[:1100,:], ignore_index=True)
    hardestbalanced = hardestbalanced.iloc[1:,:]
    hardestbalanced = hardestbalanced.sample(frac=1, random_state=myround)
    contaminated_trianset = hardestbalanced.iloc[1000:11000,:]
    hardest = hardestbalanced.iloc[:1000,:]
    data = df_cd#.drop(columns="Dffclt")
    df_train = data.iloc[:10000,:]
    df_train = df_train.append(contaminated_trianset, ignore_index=True)
    df_train = df_train.sample(frac=1, random_state=myround)
    df_test = data.iloc[20000:21000,:]
    df_test = df_test.append(hardest, ignore_index=True)
    df_test = df_test.sample(frac=1, random_state=myround)
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)
        from keras.models import load_model
        model = load_model('FashionMnistBalanced'+ str(myround) + '.h5')
        myaccBal[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3201 - accuracy: 0.8852
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4800 - accuracy: 0.8901
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2577 - accuracy: 0.9272
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.9026
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3138 - accuracy: 0.9112
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3019 - accuracy: 0.8835
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3717 - accuracy: 0.8764
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3129 - accuracy: 0.9206
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3206 - accuracy: 0.9086
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2945 - accuracy: 0.9224
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4135 - accuracy: 0.9113
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2201 - accuracy: 0.9116
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2768 - accuracy: 0.9171
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4509 - accuracy: 0.8936
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4028 - accuracy: 0.8863
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3002 - accuracy: 0.9061
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2008 - accuracy: 0.9128
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3098 - accuracy: 0.9150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3682 - accuracy: 0.8957
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2812 - accuracy: 0.9079
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3258 - accuracy: 0.9095
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8969
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4863 - accuracy: 0.8682
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3830 - accuracy: 0.8934
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3177 - accuracy: 0.9069
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2296 - accuracy: 0.9087
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4565 - accuracy: 0.8833
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4453 - accuracy: 0.8832
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3377 - accuracy: 0.9114
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3971 - accuracy: 0.8963
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2824 - accuracy: 0.9231
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5946 - accuracy: 0.8763
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3913 - accuracy: 0.8889
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3130 - accuracy: 0.9039
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3390 - accuracy: 0.8999
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2546 - accuracy: 0.9227
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3199 - accuracy: 0.9139
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3092 - accuracy: 0.9144
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4124 - accuracy: 0.8875
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3770 - accuracy: 0.8861
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.9235
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4784 - accuracy: 0.8521
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4636 - accuracy: 0.8889
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3160 - accuracy: 0.9034
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3229 - accuracy: 0.9032
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3037 - accuracy: 0.9005
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5443 - accuracy: 0.8626
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4414 - accuracy: 0.8959
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4472 - accuracy: 0.9013
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3320 - accuracy: 0.9110
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2209 - accuracy: 0.9356
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2456 - accuracy: 0.9231
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2402 - accuracy: 0.9319
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3641 - accuracy: 0.9184
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3272 - accuracy: 0.9076
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8905
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3359 - accuracy: 0.9072
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2474 - accuracy: 0.9095
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3979 - accuracy: 0.9046
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3351 - accuracy: 0.9066
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3203 - accuracy: 0.8863
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4170 - accuracy: 0.8792
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3395 - accuracy: 0.8950
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.8846
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3148 - accuracy: 0.9002
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4168 - accuracy: 0.8857
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2600 - accuracy: 0.9231
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2629 - accuracy: 0.9141
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4340 - accuracy: 0.8866
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3640 - accuracy: 0.8880
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2137 - accuracy: 0.9296
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2051 - accuracy: 0.9350
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4344 - accuracy: 0.9009
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2704 - accuracy: 0.9258
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3960 - accuracy: 0.8898
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3813 - accuracy: 0.8952
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4096 - accuracy: 0.8814
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3323 - accuracy: 0.9162
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4937 - accuracy: 0.8568
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3532 - accuracy: 0.9225
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3063 - accuracy: 0.8770
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4753 - accuracy: 0.8717
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3595 - accuracy: 0.9099
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4197 - accuracy: 0.9003
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3271 - accuracy: 0.9074
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2246 - accuracy: 0.9289
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2478 - accuracy: 0.9265
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3835 - accuracy: 0.9124
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4243 - accuracy: 0.8898
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3491 - accuracy: 0.9069
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2167 - accuracy: 0.9146
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.8676
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4409 - accuracy: 0.8615
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3349 - accuracy: 0.8932
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3195 - accuracy: 0.9132
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2678 - accuracy: 0.9337
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3280 - accuracy: 0.9111
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3036 - accuracy: 0.8974
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2985 - accuracy: 0.8954
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2822 - accuracy: 0.9179

# %%
nnBal = 0
meanPerBinBal = np.zeros(5)
for myturn in range (5):
    print((np.mean(myaccBal[:, myturn])))
    meanPerBinBal[myturn] = np.mean(myaccBal[:, myturn])
    nnBal += (np.mean(myaccBal[:, myturn]))
print(nnBal/5)
meanPerBinBal
# Out:
# 0.9075592637062073
# 0.8950984627008438
# 0.9034213721752167
# 0.8978448778390884
# 0.904573941230774
# 0.9016995835304261
# array([0.90755926, 0.89509846, 0.90342137, 0.89784488, 0.90457394])

# %%
myhistBal = np.zeros((20,5))

for myround in range(1,21):
    df_cd = df_cd_temp.sample(frac=1, random_state=myround)
    hardest= df_cd[25000:]
    hardest=hardest.sort_values('Dffclt', ascending=False)
    hardestbalanced = hardest[:1]
    for item_class in range (10):
        hardestTemp = hardest[hardest['class']==item_class]
        hardestbalanced = hardestbalanced.append(hardestTemp.iloc[:1100,:], ignore_index=True)

    hardestbalanced = hardestbalanced.iloc[1:,:]
    hardestbalanced = hardestbalanced.sample(frac=1, random_state=myround)
    #hardestbalanced=  hardestbalanced.drop(columns="Dffclt")
    contaminated_trianset = hardestbalanced.iloc[1000:11000,:]
    hardest = hardestbalanced.iloc[:1000,:]
    df_cd1=  df_cd#.drop(columns="Dffclt")
    df_train = df_cd1.iloc[:10000,:]
    df_train = df_train.append(contaminated_trianset, ignore_index=True)
    df_train = df_train.sample(frac=1, random_state=myround)
    df_train = df_train.drop(columns="Dffclt")
    df_test = df_cd1.iloc[20000:21000,:]
    df_test = df_test.append(hardest, ignore_index=True)
    df_test = df_test.sample(frac=1, random_state=myround)
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        myhistBal[myround-1,mydiff] = len(df_test_temp)
myhistBal
# Out:
# array([[ 209.,  191.,  206.,  380., 1014.],
#        [ 206.,  178.,  189.,  383., 1044.],
#        [ 203.,  215.,  205.,  357., 1020.],
#        [ 213.,  195.,  200.,  393.,  999.],
#        [ 221.,  194.,  220.,  366.,  999.],
#        [ 208.,  180.,  214.,  395., 1003.],
#        [ 195.,  194.,  207.,  385., 1019.],
#        [ 194.,  209.,  187.,  400., 1010.],
#        [ 196.,  169.,  198.,  414., 1023.],
#        [ 201.,  182.,  221.,  385., 1011.],
#        [ 202.,  208.,  191.,  392., 1007.],
#        [ 201.,  194.,  210.,  367., 1028.],
#        [ 211.,  207.,  200.,  390.,  992.],
#        [ 210.,  195.,  198.,  397., 1000.],
#        [ 199.,  200.,  212.,  364., 1025.],
#        [ 210.,  194.,  191.,  398., 1007.],
#        [ 187.,  226.,  222.,  361., 1004.],
#        [ 211.,  204.,  194.,  381., 1010.],
#        [ 199.,  204.,  195.,  365., 1037.],
#        [ 196.,  225.,  195.,  373., 1011.]])

# %%
myhistAccumBal = np.zeros (5)
for histindex in range (5):
    myhistAccumBal[histindex] = np.sum(myhistBal[:, histindex])
print(myhistAccumBal)
# Out:
# [ 4072.  3964.  4055.  7646. 20263.]

# %%
plt.xlabel("difficulty")
plt.ylabel("number of instances")
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccumBal,width=0.8, color='black')
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccum,width=0.5, color='green')
plt.bar(['0,2','2,4','4,6','6,8','8,10'], myhistAccumCont,width=0.2, color = 'red')
plt.title("number of instances per bin(green=normal dataset, red=contaminated and black=balanced)")
plt.legend(["D''","D", "D'"])
plt.show()

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
#plt.ylim([0, 100])
plt.rcParams['figure.figsize'] = [10, 6]
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont*100, ls='-', color = 'red')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls=':', color = 'green')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont_nor*100, ls='-.', color = 'blue')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal*100, ls=':', color = 'black')
plt.legend(["M',D'","M,D", "M',D","M'',D''"])
plt.show()

# %% [markdown]
# # M'' on D

# %%
myaccBal_nor = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    data = df.sample(frac=1, random_state=myround)
    df_train = data.iloc[:20000,:]
    df_test = data.iloc[20000:22000,:]
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)
        from keras.models import load_model
        model = load_model('FashionMnistBalanced'+ str(myround) + '.h5')
        myaccBal_nor[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3112 - accuracy: 0.8933
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3188 - accuracy: 0.9141
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3284 - accuracy: 0.9137
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3521 - accuracy: 0.8993
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4094 - accuracy: 0.8971
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3094 - accuracy: 0.9023
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3486 - accuracy: 0.9049
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3220 - accuracy: 0.9302
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3712 - accuracy: 0.8905
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2459 - accuracy: 0.9248
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4439 - accuracy: 0.9061
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2928 - accuracy: 0.8995
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3371 - accuracy: 0.9031
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4229 - accuracy: 0.9045
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8995
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3407 - accuracy: 0.8941
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3352 - accuracy: 0.8842
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2833 - accuracy: 0.9050
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3501 - accuracy: 0.9020
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2350 - accuracy: 0.9084
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2904 - accuracy: 0.9154
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3872 - accuracy: 0.8895
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3957 - accuracy: 0.8889
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.9008
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2826 - accuracy: 0.9055
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3103 - accuracy: 0.9047
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4632 - accuracy: 0.8766
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4296 - accuracy: 0.8959
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4298 - accuracy: 0.9020
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3746 - accuracy: 0.8917
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3926 - accuracy: 0.8976
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4599 - accuracy: 0.8886
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3573 - accuracy: 0.9000
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3535 - accuracy: 0.8955
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3819 - accuracy: 0.8932
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2745 - accuracy: 0.9162
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2653 - accuracy: 0.9260
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3361 - accuracy: 0.9065
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4363 - accuracy: 0.8936
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4990 - accuracy: 0.8684
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3792 - accuracy: 0.9075
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5168 - accuracy: 0.8613
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.8941
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3036 - accuracy: 0.8988
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2774 - accuracy: 0.9111
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2718 - accuracy: 0.9187
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4759 - accuracy: 0.8782
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2973 - accuracy: 0.9169
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3823 - accuracy: 0.9059
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3155 - accuracy: 0.9113
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3274 - accuracy: 0.9134
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2455 - accuracy: 0.9181
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3236 - accuracy: 0.9179
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4834 - accuracy: 0.8881
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3626 - accuracy: 0.8997
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3104 - accuracy: 0.8981
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3027 - accuracy: 0.9134
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2909 - accuracy: 0.9082
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4060 - accuracy: 0.9056
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3911 - accuracy: 0.8868
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3103 - accuracy: 0.9032
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3634 - accuracy: 0.8911
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3765 - accuracy: 0.8964
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2963 - accuracy: 0.9059
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3021 - accuracy: 0.9032
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3948 - accuracy: 0.8789
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2800 - accuracy: 0.9050
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.9195
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3530 - accuracy: 0.8835
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3584 - accuracy: 0.8872
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3797 - accuracy: 0.9066
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2387 - accuracy: 0.9194
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4146 - accuracy: 0.9095
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2769 - accuracy: 0.9197
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3451 - accuracy: 0.8953
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.9054
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3519 - accuracy: 0.8959
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3675 - accuracy: 0.8992
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4089 - accuracy: 0.8867
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2947 - accuracy: 0.9179
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3150 - accuracy: 0.8942
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8846
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3667 - accuracy: 0.9089
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3616 - accuracy: 0.9011
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3736 - accuracy: 0.9027
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2072 - accuracy: 0.9309
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3140 - accuracy: 0.9039
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3617 - accuracy: 0.9025
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3022 - accuracy: 0.9111
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3144 - accuracy: 0.9045
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2642 - accuracy: 0.9108
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8903
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3824 - accuracy: 0.8837
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3899 - accuracy: 0.8986
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3755 - accuracy: 0.9044
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2907 - accuracy: 0.9211
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3774 - accuracy: 0.9014
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2799 - accuracy: 0.9095
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3505 - accuracy: 0.8875
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2224 - accuracy: 0.9364

# %%
nnBal_nor = 0
meanPerBinBal_nor = np.zeros(5)
for myturn in range (5):
    print((np.mean(myaccBal_nor[:, myturn])))
    meanPerBinBal_nor[myturn] = np.mean(myaccBal_nor[:, myturn])
    nnBal_nor += (np.mean(myaccBal_nor[:, myturn]))
print(nnBal_nor/5)
meanPerBinBal_nor
# Out:
# 0.9059220075607299
# 0.8973122626543045
# 0.9054788440465927
# 0.8990319311618805
# 0.90245923101902
# 0.9020408552885055
# array([0.90592201, 0.89731226, 0.90547884, 0.89903193, 0.90245923])

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
#plt.ylim([0, 100])
#plt.figure(figsize=(20,10))
plt.rcParams['figure.figsize'] = [14, 8]
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont*100, ls='-', color = 'red')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls=':', color = 'green')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont_nor*100, ls='-.', color = 'blue')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal*100, ls=':', color = 'black')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal_nor*100, ls=':', color = 'orange')

plt.legend(["M',D'","M,D", "M',D","M'',D''","M'',D"])
plt.show()

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
#plt.ylim([0, 100])
# plt.figure(figsize=(16,8))
plt.rcParams['figure.figsize'] = [15, 8]
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont*100, ls='-', color = 'red')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls=':', color = 'green')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont_nor*100, ls='-.', color = 'blue')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal*100, ls=':', color = 'black')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal_nor*100, ls=':', color = 'orange')

plt.legend(["M',D'","M,D", "M',D","M'',D''","M'',D"])
plt.show()

# %% [markdown]
# # EasyOut

# %%
myaccEasyOut = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    df_cd = df.sample(frac=1, random_state=myround)
    hardest = df_cd[25000:]
    hardest = hardest.sort_values('Dffclt', ascending=False)
    hardest = hardest.iloc[:11000,:]
    hardest = hardest.sample(frac=1, random_state=myround)
    contaminated_trianset = hardest.iloc[:10000,:]
    hardest = hardest.iloc[10000:11000,:]
    df_easyout = df_cd .iloc[:22000,:]
    df_easyout = df_easyout.sort_values('Dffclt', ascending=True)
    df_easyout = df_easyout.iloc[6000:,:]
    df_easyout = df_easyout.sample(frac=1, random_state=myround)
    data = df_easyout#.drop(columns="Dffclt")
    df_train = data.iloc[:10000,:]
    df_train = df_train.append(contaminated_trianset, ignore_index=True)
    df_train = df_train.sample(frac=1, random_state=myround)
    df_test = data.iloc[10000:11000,:]
    df_test = df_test.append(hardest, ignore_index=True)
    df_test = df_test.sample(frac=1, random_state=myround)
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (1,5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)
        from keras.models import load_model
        model = load_model('FashionMnistEasyout'+ str(myround) + '.h5')
        myaccEasyOut[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3351 - accuracy: 0.9074
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2238 - accuracy: 0.9327
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4235 - accuracy: 0.8758
# 34/34 [==============================] - 0s 5ms/step - loss: 0.3371 - accuracy: 0.9024
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3174 - accuracy: 0.9086
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4237 - accuracy: 0.8953
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3970 - accuracy: 0.9044
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3871 - accuracy: 0.8944
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4312 - accuracy: 0.9075
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3062 - accuracy: 0.9148
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3496 - accuracy: 0.8980
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3401 - accuracy: 0.9033
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3438 - accuracy: 0.9053
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3028 - accuracy: 0.8989
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3953 - accuracy: 0.8991
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3372 - accuracy: 0.9070
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3571 - accuracy: 0.9036
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2617 - accuracy: 0.9137
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4259 - accuracy: 0.8957
# 34/34 [==============================] - 0s 4ms/step - loss: 0.3785 - accuracy: 0.8932
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4683 - accuracy: 0.8927
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3653 - accuracy: 0.8848
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4302 - accuracy: 0.9013
# 34/34 [==============================] - 0s 4ms/step - loss: 0.3150 - accuracy: 0.9007
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3888 - accuracy: 0.8969
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3219 - accuracy: 0.9216
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.9108
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3359 - accuracy: 0.9064
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4603 - accuracy: 0.8721
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1698 - accuracy: 0.9424
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4549 - accuracy: 0.8955
# 34/34 [==============================] - 0s 5ms/step - loss: 0.2906 - accuracy: 0.9140
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2584 - accuracy: 0.8912
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3055 - accuracy: 0.9059
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3779 - accuracy: 0.8897
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2941 - accuracy: 0.9106
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1992 - accuracy: 0.9333
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3032 - accuracy: 0.8997
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3363 - accuracy: 0.8940
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3122 - accuracy: 0.9110
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5278 - accuracy: 0.8836
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3996 - accuracy: 0.8973
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2665 - accuracy: 0.8933
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3307 - accuracy: 0.9071
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3096 - accuracy: 0.8797
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2552 - accuracy: 0.9242
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.8773
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3361 - accuracy: 0.9045
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2932 - accuracy: 0.8981
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2595 - accuracy: 0.9308
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3272 - accuracy: 0.9000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3830 - accuracy: 0.9013
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2550 - accuracy: 0.9091
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3049 - accuracy: 0.9134
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3549 - accuracy: 0.8995
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3363 - accuracy: 0.9044
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3670 - accuracy: 0.8820
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3432 - accuracy: 0.9173
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3462 - accuracy: 0.9063
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3862 - accuracy: 0.9060
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3117 - accuracy: 0.9202
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3334 - accuracy: 0.9024
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3853 - accuracy: 0.8966
# 34/34 [==============================] - 0s 5ms/step - loss: 0.3770 - accuracy: 0.9125
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3181 - accuracy: 0.9000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3367 - accuracy: 0.8951
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3245 - accuracy: 0.9062
# 34/34 [==============================] - 0s 5ms/step - loss: 0.3323 - accuracy: 0.9050
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3086 - accuracy: 0.8802
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3930 - accuracy: 0.8860
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3799 - accuracy: 0.9029
# 34/34 [==============================] - 0s 4ms/step - loss: 0.4348 - accuracy: 0.8877
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3555 - accuracy: 0.9162
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2648 - accuracy: 0.9239
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4055 - accuracy: 0.8725
# 35/35 [==============================] - 0s 6ms/step - loss: 0.3232 - accuracy: 0.9008
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4214 - accuracy: 0.8851
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2397 - accuracy: 0.9046
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2958 - accuracy: 0.9085
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.8932

# %%
nnEasyout = 0
meanPerBinEasyout = np.zeros(5)
for myturn in range (5):
    print((np.mean(myaccEasyOut[:, myturn])))
    meanPerBinEasyout[myturn] = np.mean(myaccEasyOut[:, myturn])
    nnEasyout += (np.mean(myaccEasyOut[:, myturn]))
print(nnEasyout/5)
meanPerBinEasyout
# Out:
# 0.9028020650148392
# 0.893926951289177
# 0.9010032594203949
# 0.9055569678544998
# 0.9050028830766678
# 0.9016584253311157
# array([0.90280207, 0.89392695, 0.90100326, 0.90555697, 0.90500288])

# %%
meanPerBinEasyout
# Out:
# array([0.90280207, 0.89392695, 0.90100326, 0.90555697, 0.90500288])

# %% [markdown]
# # Easyout on Normal

# %%
myaccEasy_nor = np.zeros((20,5))

for myround in range(1,21):
    random.seed(myround)
    np.random.seed(myround)
    tf.random.set_seed(myround)
    data = df.sample(frac=1, random_state=myround)
    df_train = data.iloc[:20000,:]
    df_test = data.iloc[22000:24000,:]
    df_train = df_train.drop(columns="Dffclt")
    for mydiff in range (5):
        df_test_temp = df_test.loc[(df_test['Dffclt'] >= (mydiff*2)) & (df_test['Dffclt'] <= ((mydiff+1)*2))]
        df_test_temp = df_test_temp.drop(columns="Dffclt")
        
        trainX = df_train.drop(columns="class")
        trainY = df_train['class']
        testX = df_test_temp.drop(columns="class")
        testY = df_test_temp['class']
        trainX=np.array(trainX)
        testX=np.array(testX)
        trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
        testX = testX.reshape((testX.shape[0], 28, 28, 1))
        trainX = trainX/255
        testX = testX/255
        trainY = np_utils.to_categorical(trainY,10)
        testY = np_utils.to_categorical(testY,10)
        from keras.models import load_model
        model = load_model('FashionMnistEasyout'+ str(myround) + '.h5')
        myaccEasy_nor[myround-1,mydiff] = (model.evaluate(testX,testY)[1])
# Out:
# 13/13 [==============================] - 3s 12ms/step - loss: 0.3843 - accuracy: 0.8927
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3797 - accuracy: 0.8904
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4614 - accuracy: 0.9007
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3448 - accuracy: 0.9016
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3066 - accuracy: 0.9133
# 13/13 [==============================] - 1s 5ms/step - loss: 0.3964 - accuracy: 0.8908
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3032 - accuracy: 0.9221
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4557 - accuracy: 0.8942
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4451 - accuracy: 0.9113
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3849 - accuracy: 0.8965
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3534 - accuracy: 0.8962
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3489 - accuracy: 0.8897
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3464 - accuracy: 0.8912
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8951
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3640 - accuracy: 0.9008
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2713 - accuracy: 0.9229
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3149 - accuracy: 0.9353
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2645 - accuracy: 0.9183
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4458 - accuracy: 0.8975
# 13/13 [==============================] - 1s 5ms/step - loss: 0.3560 - accuracy: 0.9109
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3242 - accuracy: 0.9053
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3618 - accuracy: 0.8789
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2791 - accuracy: 0.9055
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8825
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3708 - accuracy: 0.8993
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4336 - accuracy: 0.9008
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3824 - accuracy: 0.8963
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3590 - accuracy: 0.9125
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3162 - accuracy: 0.9002
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3600 - accuracy: 0.8862
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4324 - accuracy: 0.8985
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4306 - accuracy: 0.8677
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2981 - accuracy: 0.8889
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2635 - accuracy: 0.9271
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2979 - accuracy: 0.9098
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3147 - accuracy: 0.9095
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3394 - accuracy: 0.9086
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3403 - accuracy: 0.8972
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3970 - accuracy: 0.8911
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3901 - accuracy: 0.9010
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3033 - accuracy: 0.9271
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3066 - accuracy: 0.9054
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4261 - accuracy: 0.8900
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2979 - accuracy: 0.9254
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3866 - accuracy: 0.9018
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2524 - accuracy: 0.9173
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.9071
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3339 - accuracy: 0.8883
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4233 - accuracy: 0.8951
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4071 - accuracy: 0.8799
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2669 - accuracy: 0.9029
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.8987
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3213 - accuracy: 0.8982
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3964 - accuracy: 0.8922
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3211 - accuracy: 0.9080
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2292 - accuracy: 0.9233
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4111 - accuracy: 0.9071
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3077 - accuracy: 0.9147
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3817 - accuracy: 0.8904
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3081 - accuracy: 0.9158
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3096 - accuracy: 0.9023
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3210 - accuracy: 0.9103
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3456 - accuracy: 0.9137
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3091 - accuracy: 0.9192
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3528 - accuracy: 0.9002
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3533 - accuracy: 0.9038
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4659 - accuracy: 0.8648
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.9005
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4473 - accuracy: 0.8988
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3011 - accuracy: 0.8943
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3575 - accuracy: 0.8941
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2902 - accuracy: 0.9080
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2958 - accuracy: 0.8930
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3521 - accuracy: 0.8914
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4601 - accuracy: 0.8812
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3805 - accuracy: 0.8973
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3730 - accuracy: 0.9011
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4881 - accuracy: 0.8759
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3615 - accuracy: 0.8907
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4325 - accuracy: 0.8966
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4580 - accuracy: 0.8920
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2760 - accuracy: 0.9239
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3715 - accuracy: 0.9010
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3742 - accuracy: 0.8946
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.8727
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3042 - accuracy: 0.9023
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3483 - accuracy: 0.9010
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2965 - accuracy: 0.9173
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3915 - accuracy: 0.8958
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4645 - accuracy: 0.8812
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3130 - accuracy: 0.9140
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3494 - accuracy: 0.9043
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3788 - accuracy: 0.8975
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3781 - accuracy: 0.8989
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3084 - accuracy: 0.9119
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2947 - accuracy: 0.9175
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3164 - accuracy: 0.8959
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3834 - accuracy: 0.9038
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2942 - accuracy: 0.9054
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3717 - accuracy: 0.8843

# %%
nnEasy_nor = 0
meanPerBinEasy_nor = np.zeros(5)
for myturn in range (5):
    print((np.mean(myaccEasy_nor[:, myturn])))
    
    meanPerBinEasy_nor[myturn] = np.mean(myaccEasy_nor[:, myturn])
    nnEasy_nor += (np.mean(myaccEasy_nor[:, myturn]))
print(nnEasy_nor/5)
meanPerBinEasy_nor
# Out:
# 0.9055225521326065
# 0.9008202195167542
# 0.9001167207956314
# 0.9002214848995209
# 0.8972844272851944
# 0.9007930809259415
# array([0.90552255, 0.90082022, 0.90011672, 0.90022148, 0.89728443])

# %% [markdown]
# # retrieve Data

# %%
# meanPerBin = np.array([0.90857169, 0.99608696, 0.99548023, 0.97322462, 0.78041297])
# meanPerBinCont = np.array([0.91473156, 0.99643455, 0.99000095, 0.97472413, 0.83111452])
# meanPerBinCont_nor = np.array([0.90819363, 0.99643015, 0.99205411, 0.97696814, 0.83540584])
# meanPerBinBal = np.array([0.91888459, 0.99669727, 0.99260397, 0.97652241, 0.81149581])
# meanPerBinBal_nor = np.array([0.91112821, 0.99640992, 0.99121775, 0.96850775, 0.82140897])
# meanPerBinEasyout = np.array([0.914731556, 0.99643454, 0.99000095, 0.97472413, 0.83111452])
# meanPerBinEasy_nor = np.array([0.90711125, 0.99745095, 0.99606984, 0.98523711, 0.90680507])

meanPerBin = np.array([0.98172436, 0.97082751, 0.90453206, 0.72854801, 0.32281444])
meanPerBinCont = np.array([0.96705341, 0.92646382, 0.83145882, 0.63315409, 0.3506304])
meanPerBinCont_nor = np.array([0.9662719,  0.92534715, 0.82927001, 0.66595203, 0.35979176])
meanPerBinBal = np.array([0.9847377,  0.9607632,  0.86483373, 0.74642161, 0.3637459])
meanPerBinBal_nor = np.array([0.98365965, 0.95465598, 0.83465019, 0.63446882, 0.33419975])
meanPerBinEasyout = np.array([0.85974245, 0.82176724, 0.644326, 0.36531025])
meanPerBinEasy_nor = np.array([0.78782655, 0.84630507, 0.82237144, 0.67781254, 0.35908157])

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
#plt.ylim([0, 100])
# plt.figure(figsize=(16,8))
plt.rcParams['figure.figsize'] = [15, 8]
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont*100, ls='-', color = 'red')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls='-', color = 'green')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinCont_nor*100, ls='-.', color = 'blue')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal*100, ls=':', color = 'black')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinBal_nor*100, ls=':', color = 'orange')
plt.plot(['2,4','4,6','6,8','8,10'], meanPerBinEasyout*100, ls=':', color = 'purple')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinEasy_nor*100, ls=':', color = '#4649FF')


plt.legend(["M',D'","M,D", "M',D","M'',D''","M'',D", "M4, D4", "M4,D"])
#plt.legend(["M',D'","M,D", "M',D","M4, D4", "M4,D"])
plt.show()

# %%
plt.title("FashionMnist")
plt.xlabel("difficulty")
plt.ylabel("accuracy")
#plt.ylim([85, 100])
# plt.figure(figsize=(16,8))
plt.rcParams['figure.figsize'] = [15, 8]
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBin*100, ls='-', color = 'green')
plt.plot(['2,4','4,6','6,8','8,10'], meanPerBinEasyout*100, ls=':', color = 'purple')
plt.plot(['0,2','2,4','4,6','6,8','8,10'], meanPerBinEasy_nor*100, ls=':', color = '#4649FF')


plt.legend(["M,D", "M4, D4", "M4,D"])
plt.show()
